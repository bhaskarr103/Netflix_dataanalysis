# %%
# importing dataset.

import pandas as pd
data = pd.read_csv(r"D:\Vth SEM MATERIAL\Pandas\file_dsc.csv")
# r signifies to remove the unicode error.

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Gathering info**

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape # nos of rows and columns
# Out:
# (7789, 11)

# %%
data.size # Total nos of values(elements) in dataset.
# Out:
# 85679

# %%
data.columns # to show each column name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes # to show datatype of each columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info() # Show columns, not_null values count, Dtype, MemoryUsage all at once.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Removing the duplicate records in the dataset.

# %%
data.duplicated() # show corresponding boolean values on rows.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
data[data.duplicated()] # To check row-wise and detect duplicated rows
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# # Is there any NULL Value present in the column.

# %%
data.isnull()     # corresponding boolean dataframe.
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum() # Count of null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# Show null value with heatmap.

import seaborn as sns

sns.heatmap(data.isnull())
# Null values shown by white color
# Director column has maximum Null values.
# Blac - Down to Colormarker No Noll value.
# Out:
# <Axes: >

# %% [markdown]
# ** For House Of Cards, What is show_id and who's director of show ?**

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# To show all record of particular item in any column.

data[data['Title'].isin(['House of Cards'])]|
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# To show all records of a particular string in any column.

data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# **In which year Highest number of the T.V shows and movies were released**

# %%
data.dtypes # Check Release date
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# to_datetime
# data['Date_N'] = pd.to_datetime(data['Release_Date'], format="%B %d, %Y")
# data['Date_N'] = pd.to_datetime(data['Release_Date'])

data["Release_Date"] = pd.to_datetime(data['Release_Date'])
data['day_added'] = data['Release_Date'].data.day
data['year_added'] = data['Release_Date'].data.year
data['month_added']=data['Release_Date'].data.month
data['year_added'].astype(int);
data['day_added'].astype(int);

# %% [markdown]
# **How many TV and movie shows are in the dataset**

# %%
# to group all unique items of a column and show their count.

print(str(data.groupby('Category').count()),'\n\n')

data.groupby('Category').Category.count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5379   5379      5216  4953     5149          5379    5374
# TV Show      2410   2410       185  2118     2133          2400    2408
#
#           Duration  Type  Description
# Category
# Movie         5379  5379         5379
# TV Show       2410  2410         2410
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
# countplot()

import seaborn as sns
import matplotlib.pyplot as plt

colors = ['blue', 'pink']
plt.figure(figsize=(5, 5))
ax = sns.countplot(data=data, x='Category', palette=colors)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='baseline')
plt.show()

# %% [markdown]
# **Show all movies that were released in year 2000**

# %% [markdown]
# **Filtering**

# %%
data[(data['Category'] == 'Movie') & (data['Year']==2020)]

# %% [markdown]
# **Show only the Title of all T.V Shows that were released in India Only**

# %%
data[(data['Country']=='India') & (data['Category']=='TV Show')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# **Show top 10 directors, who gave highest number of TV Shows and movies to Netflix.**

# %%
data['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Elle Callahan              1
# Sam Dunn                   1
# Name: count, Length: 4050, dtype: int64

# %% [markdown]
# **Show all the records where category is 'movie' Type is 'comedy' or Country is 'United States'**

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedy') | (data['Country']=='United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# **In how many movies/shows Tom Cruise was cast**

# %%
data[data['Cast'] == 'Tom Cruise'] # using fltering

data[data['Cast'].str.contains('Tom Cruise')]

# %%
# Removing null values so that above func work.

data_new = data.dropna()

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# **What are the different ratings defined by Netflix**

# %%
data.groupby('Rating', as_index=False).count().Rating
# Out:
# 0            G
# 1        NC-17
# 2           NR
# 3           PG
# 4        PG-13
# 5            R
# 6        TV-14
# 7         TV-G
# 8        TV-MA
# 9        TV-PG
# 10        TV-Y
# 11       TV-Y7
# 12    TV-Y7-FV
# 13          UR
# Name: Rating, dtype: object

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
fig = plt.figure(figsize=(5,4))
sns.countplot(data['Rating'])
sns.countplot(data['Rating']).set_xticklabels(sns.countplot(data['Rating']).get_xticklabels(), rotation=90, ha="right")
plt.title('Rating')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3144\1521637462.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sns.countplot(data['Rating']).set_xticklabels(sns.countplot(data['Rating']).get_xticklabels(), rotation=90, ha="right")
# Text(0.5, 1.0, 'Rating')

# %%
data['Rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(9,8))
plt.show()

# %% [markdown]
# **How many movies/TV show got the TV-14 Rating in Canada**

# %%
data[(data['Rating']=='TV-14') & (data['Country']=='Canada')].shape
# Out:
# (23, 11)

# %% [markdown]
# **How many movies got rating R after 2018**

# %%
data[(data['Category']=='TV Show')&(data['Rating']=='R')(data['Year'] > 2018)]

# %% [markdown]
# **What is maximum duration of TV/Show on Netflix**

# %%
data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df = pd.read_csv(r"D:\Vth SEM MATERIAL\Pandas\file_dsc.csv",
usecols=['Category','Duration'])

# Use boolean indexing to drop rows with 'Seasons' in Column1
df = df[~df['Duration'].str.endswith('Seasons')]
df = df[~df['Duration'].str.endswith('Season')]

print(df)
# Out:
#      Category Duration
# 1       Movie   93 min
# 2       Movie   78 min
# 3       Movie   80 min
# 4       Movie  123 min
# 6       Movie   95 min
# ...       ...      ...
# 7783    Movie   88 min
# 7784    Movie   99 min
# 7785    Movie  111 min
# 7786    Movie   44 min
# 7788    Movie   90 min
#
# [5379 rows x 2 columns]

# %%
# Pie chart for the type :- Movies and TV Shows

labels = ['Movie', 'TV show']
size = data['Category'].value_counts()  # Movie -> 5379, TV Show -> 2410
explode = [0, 0.2]
plt.rcParams['figure.figsize'] = (7, 7)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# **Categories using wordcloud**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=650,
                          height=650
                         ).generate(" ".join(data.Type))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()
